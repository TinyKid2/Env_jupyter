# %%
# %pip install bs4
import requests as re
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: /Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
res = re.get("http://www.example.com")
res.text
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %%
from bs4 import BeautifulSoup

soup= BeautifulSoup(res.text, "html.parser") # html parser를 사용할 것이다 라고 명시

print(soup.prettify()) # 보기 편한 형태로 출력해줌.
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Example Domain
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <style type="text/css">
#    body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#   </style>
#  </head>
# ...

# %%
soup.title
# Out:
# <title>Example Domain</title>

# %%
soup.head
# Out:
# <head>
# <title>Example Domain</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>

# %%
soup.body
# Out:
# <body>
# <div>
# <h1>Example Domain</h1>
# <p>This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.</p>
# <p><a href="https://www.iana.org/domains/example">More information...</a></p>
# </div>
# </body>

# %%
# 특정 바디를 찾는것


h1 = soup.find("h1")#특정 태그를 넣음 # 1개 # 제일 먼저 나오는 것만 출력

p_find = soup.find_all("p")# 특정요소 여러개

h1.name
# Out:
# 'h1'

# %% [markdown]
# ## Example
#
# Target: Mock Book Data
# 다음 사이트에 있는 책들의 이름 정보를 스크래핑 해봅시다 : http://books.toscrape.com/catalogue/category/books/travel_2/index.html
#
# 해당 웹 페이지는 임의의 책 정보가 담긴 웹 사이트입니다.
#
# 우리의 목표 : 책의 제목을 모두 가져오는 것.

# %% [markdown]
# # 개발자도구 (command + opt + f12)
# - 오른쪽 클릭 ,검사 --> http에서 어디에 있는지 하이라이트로 알려줌
# - 우리의 문제는 저 정보를 어떻게 가져올 것인가 이다.
# - h3로 제목을 가져오면 되는것을 눈치 챔
# - 그것을 가져오려니, 다양한 태그로 ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get("http://books.toscrape.com/catalogue/category/books/travel_2/index.html")
# 요청을 보냄
soup = BeautifulSoup(res.text, "html.parser")
print(soup)
# 분석까지 끝남
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     Travel |
#      Books to Scrape - Sandbox
#
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="
#
# " name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="../../../../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
soup.find("h3") # 태그들
# Out:
# <h3><a href="../../../its-only-the-himalayas_981/index.html" title="It's Only the Himalayas">It's Only the Himalayas</a></h3>

# %%
h3_res= soup.find_all("h3") # 모든 요소를 가져온것

h3_res[0]
# Out:
# <h3><a href="../../../its-only-the-himalayas_981/index.html" title="It's Only the Himalayas">It's Only the Himalayas</a></h3>

# %% [markdown]
# <a href="../../../its-only-the-himalayas_981/index.html" title="It's Only the Himalayas">It's Only the Himalayas</a>
#
# 이것이 pasing문자

# %%
# 특정 요소를 가져올것 # 이곳에서는 제목

# for book in h3_res:
#     print(book.a.text)
    # 문자가 잘려 있기에 이렇게 나오는 것.
    
for book in h3_res:
    print(book.a["title"])
    # title이라는 속성 속에는 제목의 전체 문자가 들어 있기에, title이라는 것을 사용
    # dictionary형태를 가지고 있으므로, dict 처럼 사용
# Out:
# It's Only the Himalayas
# Full Moon over Noahâs Ark: An Odyssey to Mount Ararat and Beyond
# See America: A Celebration of Our National Parks & Treasured Sites
# Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel
# Under the Tuscan Sun
# A Summer In Europe
# The Great Railway Bazaar
# A Year in Provence (Provence #1)
# The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)
# Neither Here nor There: Travels in Europe
# 1,000 Places to See Before You Die

# %% [markdown]
# # locator로 찾기
#
# id : 고유태그
# class : 여러 태그를 묶는 라벨

# %%
import requests
from bs4 import BeautifulSoup

# http://example.python-scraping.com

res = requests.get("https://www.naver.com/")

soup = BeautifulSoup(res.text, "html.parser")

# id는 겹칠수 없음

soup.find("div")
# 이것은 안좋은 방법
# Out:
# <div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div>

# %%
print(soup.find("ul", id = "NM_THEME_CATE_LIST"))
# Out:
# <ul class="list_category" data-index="0" id="NM_THEME_CATE_LIST" role="tablist">
# <li class="category_item" role="presentation">
# <a aria-controls="NM_THEME_CONTAINER" aria-selected="false" class="_NM_THEME_CATE tab id_enter" data-clk="tct.tvc" data-panel-code="ENTER" href="#" role="tab">엔터</a>
# </li>
# <li class="category_item" role="presentation">
# <a aria-controls="NM_THEME_CONTAINER" aria-selected="false" class="_NM_THEME_CATE tab id_sports" data-clk="tct.spo" data-panel-code="SPORTS" href="#" role="tab">스포츠</a>
# </li>
# <li class="category_item" role="presentation">
# <a aria-controls="NM_THEME_CONTAINER" aria-selected="false" class="_NM_THEME_CATE tab id_cargame" data-clk="tct.aut" data-panel-code="CARGAME" href="#" role="tab">자동차</a>
# </li>
# <li class="category_item" role="presentation">
# <a aria-controls="NM_THEME_CONTAINER" aria-selected="false" class="_NM_THEME_CATE tab id_bboom" data-clk="tct.web" data-panel-code="BBOOM" href="#" role="tab">웹툰</a>
# </li>
# ...

# %%
find_res = soup.find("li","category_item")
find_result.li
# Out:
# <li class="category_item" role="presentation">
# <a aria-controls="NM_THEME_CONTAINER" aria-selected="false" class="_NM_THEME_CATE tab id_enter" data-clk="tct.tvc" data-panel-code="ENTER" href="#" role="tab">엔터</a>
# </li>

# %% [markdown]
# # hashcode 질문 모으기
#
# 스크래핑하고자 하는 사이트 확인하기
# 직접 접속해서 해당 사이트를 확인해봅시다 : https://hashcode.co.kr/
# 목표 : 제목들을 scraping
#
# 1. 과도한 요청 x
# 2. 정보활용 유의
